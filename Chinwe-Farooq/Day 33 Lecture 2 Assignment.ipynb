# %% [markdown]
# ## Day 33 Lecture 2 Assignment
#
# In this assignment, we will learn about non linear SVM models. We will use the heart disease dataset loaded below and analyze the model generated for this dataset.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
heart = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/framingham_heart_disease.csv')

# %%
heart.head()
# Out:
#    male  age  education  currentSmoker  ...    BMI  heartRate  glucose  TenYearCHD
# 0     1   39        4.0              0  ...  26.97       80.0     77.0           0
# 1     0   46        2.0              0  ...  28.73       95.0     76.0           0
# 2     1   48        1.0              1  ...  25.34       75.0     70.0           0
# 3     0   61        3.0              1  ...  28.58       65.0    103.0           1
# 4     0   46        3.0              1  ...  23.10       85.0     85.0           0
#
# [5 rows x 16 columns]

# %% [markdown]
# This dataset helps us predict the probability of coronary heart diease (CHD) in the next 10 years given the risk factors for each subject in the study. Our target variable is `TenYearCHD`.
#
# We'll start off by removing any rows containing missing data.

# %%
# answer below:
heart.info()
h_df = heart.dropna(axis = 0)
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
# male               4238 non-null int64
# age                4238 non-null int64
# education          4133 non-null float64
# currentSmoker      4238 non-null int64
# cigsPerDay         4209 non-null float64
# BPMeds             4185 non-null float64
# prevalentStroke    4238 non-null int64
# prevalentHyp       4238 non-null int64
# diabetes           4238 non-null int64
# totChol            4188 non-null float64
# sysBP              4238 non-null float64
# diaBP              4238 non-null float64
# BMI                4219 non-null float64
# heartRate          4237 non-null float64
# glucose            3850 non-null float64
# TenYearCHD         4238 non-null int64
# dtypes: float64(9), int64(7)
# memory usage: 529.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3656 entries, 0 to 4237
# Data columns (total 16 columns):
# male               3656 non-null int64
# age                3656 non-null int64
# education          3656 non-null float64
# currentSmoker      3656 non-null int64
# cigsPerDay         3656 non-null float64
# BPMeds             3656 non-null float64
# prevalentStroke    3656 non-null int64
# prevalentHyp       3656 non-null int64
# diabetes           3656 non-null int64
# totChol            3656 non-null float64
# sysBP              3656 non-null float64
# diaBP              3656 non-null float64
# BMI                3656 non-null float64
# heartRate          3656 non-null float64
# glucose            3656 non-null float64
# TenYearCHD         3656 non-null int64
# dtypes: float64(9), int64(7)
# memory usage: 485.6 KB

# %% [markdown]
# We will then scale the data using the standard scaler. Do this in the cell below.

# %%
# answer below:
X = h_df.drop('TenYearCHD', axis = 1)
y = h_df['TenYearCHD']

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X, y)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# Finally, we wil split the data into train and test with 20% of the data in the test subset.

# %%
# answer below:
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 33)

# %%
# We would like to compare the runtime of a number of functions later in our code. 
import time 
import timeit
start_time = time.time() 
print("--- %s seconds ---" % (time.time() - start_time))

from sklearn.svm import SVC
# Out:
# --- 3.4809112548828125e-05 seconds ---

# %% [markdown]
# Generate a polynomial SVC model and a RBF SVC model. Compare the score for the two models on the test data and also compare the runtime of the two models.

# %%
clfp = SVC(kernel = 'poly', gamma = 'scale', degree = 5, probability = True, C = .1)
start_time = time.time() 

clfp.fit(X_train, y_train)

poly_trscore = clfp.score(X_train, y_train)

poly_score = clfp.score(X_test, y_test)

print ('Polynomial train score ', poly_trscore)
print ('Polynomial test score ', poly_score)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# answer below:
clf = SVC(kernel = 'rbf', gamma = 'scale', probability = True, C = .1)
start_time = time.time() 

clf.fit(X_train, y_train)

rbf_trscore = clf.score(X_train, y_train)

rbf_score = clf.score(X_test, y_test)

print ('RBF train score ', rbf_trscore)
print ('RBF test score ', rbf_score)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# RBF train score  0.8481532147742818
# RBF test score  0.8456284153005464
# --- 1.080958604812622 seconds ---

# %% [markdown]
# Which model overfits more? Why? How would you improve the model that overfits more?

# %% [markdown]
# In the Polynomial kernel the SVC model overfits more than in the RBF kernel.
#
# We can reduce overfitting by reducing the C parameter.
