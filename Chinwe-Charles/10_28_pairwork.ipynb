# %% [markdown]
# Check for mixed data types and “bad” values (text in numeric columns, categorical features coded as continuous, nulls coded as some other value)
#
# Group your like data types together when they should be treated similarly
#
# Experiment with converting non-numeric variables to numeric
#
# Check for missing values and try some different missingness handling techniques
#
# Make a couple of basic plots of a few of your variables and notice the effects of using different methods on those plots
#
# Keep track of your index, especially if you are removing rows

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn
seaborn.set()
from scipy import stats
# Out:
# C:\Users\cepyp\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#Zip file contains only the csv, so you can access it directly with read_csv
df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/diabetic-data-cleaning.zip', compression='zip')

# #Read through this and figure out what we're doing here
# for col in df.describe().columns: nanidx = df[col].sample(frac=np.random.uniform(0.0, 0.001)).index df.loc[nanidx, col] = '?'

# # Zip file contains only the csv, so you can access it directly with read_csv df = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/diabetic-data-cleaning.zip', compression='zip')

# #Read through this and figure out what we're doing here
# for col in df.describe().columns: nanidx = df[col].sample(frac=np.random.uniform(0.0, 0.001)).index df.loc[nanidx, col] = '?'

# %%
for col in df.describe().columns:
    nanidx = df[col].sample(frac=np.random.uniform(0.0, 0.001)).index 
    df.loc[nanidx, col] = '?'

# %%
df.head(15).transpose()
# Out:
#                                                 0          1   \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null object
# patient_nbr                 101766 non-null object
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      101766 non-null object
# admission_type_id           101766 non-null object
# discharge_disposition_id    101766 non-null object
# admission_source_id         101766 non-null object
# time_in_hospital            101766 non-null object
# payer_code                  101766 non-null object
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null object
# num_procedures              101766 non-null object
# num_medications             101766 non-null object
# number_outpatient           101766 non-null object
# ...

# %% [markdown]
# Ordinal -
# Nominal -
# Interval -
# Ratio -

# %%
df.nunique()
# Out:
# encounter_id                101668
# patient_nbr                  71487
# race                             6
# gender                           4
# age                             11
# weight                          10
# admission_type_id                9
# discharge_disposition_id        27
# admission_source_id             18
# time_in_hospital                15
# payer_code                      18
# medical_specialty               73
# num_lab_procedures             119
# num_procedures                   8
# num_medications                 76
# number_outpatient               40
# number_emergency                34
# number_inpatient                22
# diag_1                         716
# diag_2                         749
# diag_3                         790
# number_diagnoses                17
# max_glu_serum                    5
# A1Cresult                        5
# metformin                        5
# repaglinide                      5
# nateglinide                      5
# ...

# %%
df['race'].value_counts()
# Out:
# Caucasian          76049
# AfricanAmerican    19192
# ?                   2344
# Hispanic            2037
# Other               1505
# Asian                639
# Name: race, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Female             54686
# Male               47045
# ?                     32
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
df2=df.copy()

# %%
df2['gender']
df2['gender'] = df2['gender'].replace(('?', 'Unknown/Invalid'), np.nan)

# %%
df2['gender'].isnull().sum()
# Out:
# 35

# %%
df2.dropna(subset = ['gender'], inplace = True)
df2['gender'].isnull().sum()
# Out:
# 0

# %%
df['time_in_hospital'].dtype
# Out:
# dtype('O')

# %%
df2['time_in_hospital'] = df2['time_in_hospital'].replace('?', np.nan)
df2['time_in_hospital'] = pd.to_numeric(df2['time_in_hospital'], errors = 'ignore')
#df2['time_in_hospital'].fillna(df2['time_in_hospital'].median(), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna)
#     381     if not is_float_dtype(values):
# --> 382         values = values.astype('f8')
#     383         values[mask] = np.nan
#
# TypeError: float() argument must be a string or a number, not 'function'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-ac04144e0c74> in <module>()
#       1 df2['time_in_hospital'] = df2['time_in_hospital'].replace('?', np.nan)
# ...

# %%
df2['time_in_hospital'].value_counts()
# Out:
# 3                                          17747
# 2                                          17204
# 1                                          14199
# 4                                          13919
# 5                                           9956
# 6                                           7533
# 7                                           5855
# 8                                           4389
# 9                                           3000
# 10                                          2341
# 11                                          1855
# 12                                          1448
# 13                                          1209
# 14                                          1042
# <function median at 0x000001B3E701D9D8>       34
# Name: time_in_hospital, dtype: int64
